# %%
from scipy.stats import binom

n = 25 
p1 = 0.9
p2 = 0.1

case1 = binom.sf(12, n, p1)
print(f"Case 1 (p=0.9): P(k >= 13) = {case1}")

case2 = binom.cdf(12, n, p2)
print(f"Case 2 (p=0.1): P(k < 13) = {case2}")
# Out:
# Case 1 (p=0.9): P(k >= 13) = 0.999999837916584
# Case 2 (p=0.1): P(k < 13) = 0.999999837916584
